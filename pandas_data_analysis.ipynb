# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_json('D:\\DATA_SCIENCE\\eshank_course\\study_materials\\numpy_pandas\\PANDAS  DATA\\employee_data.json')
data
# Out:
#                                               features
# 0    {'candidate': {'first_name': 'Margaret', 'last...
# 1    {'candidate': {'first_name': 'Michael', 'last_...
# 2    {'candidate': {'first_name': 'Brenda', 'last_n...
# 3    {'candidate': {'first_name': 'Joseph', 'last_n...
# 4    {'candidate': {'first_name': 'Laura', 'last_na...
# ..                                                 ...
# 495  {'candidate': {'first_name': 'Robert', 'last_n...
# 496  {'candidate': {'first_name': 'Lucas', 'last_na...
# 497  {'candidate': {'first_name': 'Kimberly', 'last...
# 498  {'candidate': {'first_name': 'Karla', 'last_na...
# 499  {'candidate': {'first_name': 'Mrs.', 'last_nam...
#
# [500 rows x 1 columns]

# %%
lst = []
for i in data['features']:
    lst.append(i['candidate'])
df = pd.DataFrame(lst)
df
# Out:
#     first_name   last_name                                             skills  \
# 0     Margaret    Mcdonald                [skLearn, Java, R, SQL, Spark, C++]
# 1      Michael      Carter          [TensorFlow, R, Spark, MongoDB, C++, SQL]
# 2       Brenda       Tyler                                            [Spark]
# 3       Joseph        King  [skLearn, SQL, R, Spark, Java, C++, Python, Te...
# 4        Laura        Webb           [TensorFlow, C++, SQL, Java, R, MongoDB]
# ..         ...         ...                                                ...
# 495     Robert       Baker                        [skLearn, Spark, C++, Java]
# 496      Lucas       Brock                                              [C++]
# 497   Kimberly  Richardson                                     [Python, Java]
# 498      Karla     Salazar                   [MongoDB, Python, Java, skLearn]
# 499       Mrs.       Debra  [skLearn, R, MongoDB, Spark, TensorFlow, Java,...
#
# ...

# %%
df.head()
# Out:
#   first_name last_name                                             skills  \
# 0   Margaret  Mcdonald                [skLearn, Java, R, SQL, Spark, C++]
# 1    Michael    Carter          [TensorFlow, R, Spark, MongoDB, C++, SQL]
# 2     Brenda     Tyler                                            [Spark]
# 3     Joseph      King  [skLearn, SQL, R, Spark, Java, C++, Python, Te...
# 4      Laura      Webb           [TensorFlow, C++, SQL, Java, R, MongoDB]
#
#   state         specialty experience relocation
# 0    AL          Database        Mid         no
# 1    AR        Statistics     Senior        yes
# 2    UT          Database        Mid         no
# 3    FL  Machine Learning     Senior      maybe
# 4    WY  Machine Learning     Junior      maybe

# %%
df.tail()
# Out:
#     first_name   last_name                                             skills  \
# 495     Robert       Baker                        [skLearn, Spark, C++, Java]
# 496      Lucas       Brock                                              [C++]
# 497   Kimberly  Richardson                                     [Python, Java]
# 498      Karla     Salazar                   [MongoDB, Python, Java, skLearn]
# 499       Mrs.       Debra  [skLearn, R, MongoDB, Spark, TensorFlow, Java,...
#
#     state           specialty experience relocation
# 495    WA    Machine Learning        Mid        yes
# 496    AR    Machine Learning     Junior         no
# 497    IA    Machine Learning     Junior      maybe
# 498    NE  Data Visualization     Senior        yes
# 499    TX          Statistics     Senior         no

# %%
df.set_index('state',inplace=True)
df.sort_values('state')
# Out:
#       first_name  last_name  \
# state
# AK     Christine     Walker
# AK      Brittany     Nelson
# AK     Katherine   Bradshaw
# AK        Deanna       Diaz
# AK     Katherine  Christian
# ...          ...        ...
# WY         Haley       Reed
# WY        Travis     Willis
# WY       Miranda   Mitchell
# WY         Peter     Torres
# WY       Dominic     Rivera
#
#                                                   skills         specialty  \
# state
# AK     [Python, C++, TensorFlow, Java, Spark, skLearn...  Machine Learning
# AK     [Java, TensorFlow, skLearn, MongoDB, Spark, SQ...        Statistics
# AK              [Java, R, skLearn, C++, MongoDB, Python]        Statistics
# AK     [TensorFlow, skLearn, R, C++, SQL, Spark, Python]  Machine Learning
# AK                                          [Spark, C++]        Statistics
# ...                                                  ...               ...
# WY                       [R, SQL, Java, skLearn, Python]        Statistics
# ...

# %%
df.describe()
# Out:
#        first_name last_name   skills specialty experience relocation
# count         500       500      500       500        500        500
# unique        243       308      428         4          3          3
# top       Michael     Jones  [Spark]  Database        Mid         no
# freq           16        10       11       137        179        172

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, AL to TX
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  500 non-null    object
#  1   last_name   500 non-null    object
#  2   skills      500 non-null    object
#  3   specialty   500 non-null    object
#  4   experience  500 non-null    object
#  5   relocation  500 non-null    object
# dtypes: object(6)
# memory usage: 27.3+ KB

# %%
df.memory_usage(deep=True)
# Out:
# Index         29500
# first_name    31474
# last_name     31539
# skills        52128
# specialty     34838
# experience    30963
# relocation    30158
# dtype: int64

# %%
df.shape
# Out:
# (500, 6)

# %%
v=df.columns
b=sorted(v)
b
# Out:
# ['experience', 'first_name', 'last_name', 'relocation', 'skills', 'specialty']

# %%
df[b]
# Out:
#       experience first_name   last_name relocation  \
# state
# AL           Mid   Margaret    Mcdonald         no
# AR        Senior    Michael      Carter        yes
# UT           Mid     Brenda       Tyler         no
# FL        Senior     Joseph        King      maybe
# WY        Junior      Laura        Webb      maybe
# ...          ...        ...         ...        ...
# WA           Mid     Robert       Baker        yes
# AR        Junior      Lucas       Brock         no
# IA        Junior   Kimberly  Richardson      maybe
# NE        Senior      Karla     Salazar        yes
# TX        Senior       Mrs.       Debra         no
#
#                                                   skills           specialty
# state
# AL                   [skLearn, Java, R, SQL, Spark, C++]            Database
# AR             [TensorFlow, R, Spark, MongoDB, C++, SQL]          Statistics
# UT                                               [Spark]            Database
# ...

# %%
df['specialty'].unique()
# Out:
# array(['Database', 'Statistics', 'Machine Learning', 'Data Visualization'],
#       dtype=object)

# %%
df['specialty'].nunique()
# Out:
# 4

# %%
df['specialty'].count()
# Out:
# 500

# %%
df['specialty'].value_counts()
# Out:
# Database              137
# Statistics            133
# Data Visualization    116
# Machine Learning      114
# Name: specialty, dtype: int64

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of       first_name   last_name  \
# state
# AL      Margaret    Mcdonald
# AR       Michael      Carter
# UT        Brenda       Tyler
# FL        Joseph        King
# WY         Laura        Webb
# ...          ...         ...
# WA        Robert       Baker
# AR         Lucas       Brock
# IA      Kimberly  Richardson
# NE         Karla     Salazar
# TX          Mrs.       Debra
#
#                                                   skills           specialty  \
# state
# AL                   [skLearn, Java, R, SQL, Spark, C++]            Database
# AR             [TensorFlow, R, Spark, MongoDB, C++, SQL]          Statistics
# UT                                               [Spark]            Database
# FL     [skLearn, SQL, R, Spark, Java, C++, Python, Te...    Machine Learning
# WY              [TensorFlow, C++, SQL, Java, R, MongoDB]    Machine Learning
# ...                                                  ...                 ...
# ...

# %%
df1 = df.explode('skills')
df1
# Out:
#       first_name last_name      skills   specialty experience relocation
# state
# AL      Margaret  Mcdonald     skLearn    Database        Mid         no
# AL      Margaret  Mcdonald        Java    Database        Mid         no
# AL      Margaret  Mcdonald           R    Database        Mid         no
# AL      Margaret  Mcdonald         SQL    Database        Mid         no
# AL      Margaret  Mcdonald       Spark    Database        Mid         no
# ...          ...       ...         ...         ...        ...        ...
# TX          Mrs.     Debra  TensorFlow  Statistics     Senior         no
# TX          Mrs.     Debra        Java  Statistics     Senior         no
# TX          Mrs.     Debra         SQL  Statistics     Senior         no
# TX          Mrs.     Debra      Python  Statistics     Senior         no
# TX          Mrs.     Debra         C++  Statistics     Senior         no
#
# [2468 rows x 6 columns]

# %%
df1['skills'].unique()
# Out:
# array(['skLearn', 'Java', 'R', 'SQL', 'Spark', 'C++', 'TensorFlow',
#        'MongoDB', 'Python'], dtype=object)

# %%
df1['skills'].value_counts()
# Out:
# Spark         285
# TensorFlow    280
# SQL           277
# C++           274
# MongoDB       274
# Python        272
# R             272
# Java          267
# skLearn       267
# Name: skills, dtype: int64

# %%
df1.loc[df1['skills']=='C++']
# Out:
#       first_name last_name skills           specialty experience relocation
# state
# AL      Margaret  Mcdonald    C++            Database        Mid         no
# AR       Michael    Carter    C++          Statistics     Senior        yes
# FL        Joseph      King    C++    Machine Learning     Senior      maybe
# WY         Laura      Webb    C++    Machine Learning     Junior      maybe
# OK        Cheryl   Ramirez    C++  Data Visualization        Mid         no
# ...          ...       ...    ...                 ...        ...        ...
# NM           Ms.     Tracy    C++  Data Visualization        Mid      maybe
# MO       Brandon     Moore    C++    Machine Learning        Mid         no
# WA        Robert     Baker    C++    Machine Learning        Mid        yes
# AR         Lucas     Brock    C++    Machine Learning     Junior         no
# TX          Mrs.     Debra    C++          Statistics     Senior         no
#
# [274 rows x 6 columns]

# %%
df1.loc[df1['skills']=='C++'].count()
# Out:
# first_name    274
# last_name     274
# skills        274
# specialty     274
# experience    274
# relocation    274
# dtype: int64

# %%
df1.loc[df1["skills"].str.contains("R")]
# Out:
#       first_name last_name skills           specialty experience relocation
# state
# AL      Margaret  Mcdonald      R            Database        Mid         no
# AR       Michael    Carter      R          Statistics     Senior        yes
# FL        Joseph      King      R    Machine Learning     Senior      maybe
# WY         Laura      Webb      R    Machine Learning     Junior      maybe
# OK        Cheryl   Ramirez      R  Data Visualization        Mid         no
# ...          ...       ...    ...                 ...        ...        ...
# NH          Jill    Harmon      R            Database        Mid         no
# AK          Mark  Mcknight      R    Machine Learning     Senior        yes
# AL      Jennifer    Harris      R            Database     Senior        yes
# MO       Brandon     Moore      R    Machine Learning        Mid         no
# TX          Mrs.     Debra      R          Statistics     Senior         no
#
# [272 rows x 6 columns]

# %%
np.where(df1["experience"]=="Junior")
# Out:
# (array([  21,   22,   23,   24,   25,   26,   51,   52,   53,   54,   55,
#           56,   57,   70,   71,   72,   73,   74,   75,   76,   88,   89,
#           90,   91,   92,   93,   94,   95,   96,   97,  100,  101,  102,
#          103,  104,  105,  106,  107,  108,  109,  119,  120,  130,  131,
#          132,  133,  134,  142,  143,  150,  151,  152,  153,  154,  155,
#          156,  157,  158,  159,  160,  161,  162,  163,  164,  165,  204,
#          205,  206,  207,  208,  209,  210,  211,  212,  213,  214,  220,
#          221,  222,  238,  239,  240,  241,  242,  243,  244,  245,  253,
#          254,  255,  256,  276,  277,  278,  279,  280,  304,  305,  306,
#          307,  308,  309,  310,  311,  312,  313,  314,  324,  325,  326,
#          327,  328,  329,  330,  346,  347,  348,  349,  350,  351,  352,
#          353,  354,  355,  356,  357,  358,  359,  360,  361,  362,  363,
#          364,  365,  366,  367,  368,  369,  370,  371,  372,  373,  374,
# ...

# %%
df1.dtypes
# Out:
# first_name    object
# last_name     object
# skills        object
# specialty     object
# experience    object
# relocation    object
# dtype: object

# %%
skill=df[["first_name","last_name","skills"]]
skill
# Out:
#       first_name   last_name  \
# state
# AL      Margaret    Mcdonald
# AR       Michael      Carter
# UT        Brenda       Tyler
# FL        Joseph        King
# WY         Laura        Webb
# ...          ...         ...
# WA        Robert       Baker
# AR         Lucas       Brock
# IA      Kimberly  Richardson
# NE         Karla     Salazar
# TX          Mrs.       Debra
#
#                                                   skills
# state
# AL                   [skLearn, Java, R, SQL, Spark, C++]
# AR             [TensorFlow, R, Spark, MongoDB, C++, SQL]
# UT                                               [Spark]
# FL     [skLearn, SQL, R, Spark, Java, C++, Python, Te...
# WY              [TensorFlow, C++, SQL, Java, R, MongoDB]
# ...                                                  ...
# WA                           [skLearn, Spark, C++, Java]
# AR                                                 [C++]
# IA                                        [Python, Java]
# ...

# %%
df.describe(include="object")
# Out:
#        first_name last_name   skills specialty experience relocation
# count         500       500      500       500        500        500
# unique        243       308      428         4          3          3
# top       Michael     Jones  [Spark]  Database        Mid         no
# freq           16        10       11       137        179        172

# %%
sorted(df["first_name"])
# Out:
# ['Aaron',
#  'Aaron',
#  'Adam',
#  'Adam',
#  'Adrian',
#  'Alejandro',
#  'Alexander',
#  'Alexandra',
#  'Alexis',
#  'Alyssa',
#  'Alyssa',
#  'Amanda',
#  'Amber',
#  'Amber',
#  'Amy',
#  'Amy',
#  'Andrea',
#  'Andrew',
#  'Andrew',
#  'Andrew',
#  'Angela',
#  'Ann',
#  'Ann',
#  'Anthony',
#  'Anthony',
#  'April',
#  'April',
#  'Ariel',
#  'Ashley',
#  'Ashley',
#  'Ashley',
#  'Ashley',
#  'Ashley',
#  'Austin',
#  'Barbara',
#  'Benjamin',
#  'Benjamin',
#  'Beth',
#  'Beverly',
#  'Bradley',
#  'Bradley',
#  'Bradley',
#  'Brandon',
#  'Brandy',
#  'Breanna',
#  'Brenda',
#  'Brenda',
#  'Brett',
#  'Brett',
#  'Brett',
#  'Brian',
#  'Brian',
#  'Briana',
#  'Brittany',
#  'Brittany',
#  'Bruce',
#  'Bryan',
#  'Carl',
#  'Carl',
#  'Carla',
#  'Carlos',
#  'Carolyn',
#  'Carolyn',
#  'Carrie',
#  'Carrie',
#  'Cassandra',
#  'Cassidy',
#  'Catherine',
#  'Catherine',
#  'Charlene',
#  'Charles',
#  'Charles',
#  'Cheryl',
#  'Cheryl',
#  'Chris',
#  'Christina',
# ...
