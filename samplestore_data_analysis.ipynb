# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'D:\\DATA_SCIENCE\\readmycourse\\assignments'

# %%
data=pd.read_excel("D:\\DATA_SCIENCE\\readmycourse\\study_materials\\numpy_pandas\\PANDAS  DATA\\Sample_Superstore.xls", index_col="Order ID")
data
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156       1 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-152156       2 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-138688       3 2016-06-12 2016-06-16    Second Class    DV-13045
# US-2015-108966       4 2015-10-11 2015-10-18  Standard Class    SO-20335
# US-2015-108966       5 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...                ...        ...        ...             ...         ...
# CA-2014-110422    9990 2014-01-21 2014-01-23    Second Class    TB-21400
# CA-2017-121258    9991 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9992 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9993 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-119914    9994 2017-05-04 2017-05-09    Second Class    CC-12220
#
#                    Customer Name    Segment        Country             City  \
# ...

# %%
data.drop("Row ID",axis=1,inplace=True)

# %%
data.head(4)
# Out:
#                Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# CA-2016-152156    Kentucky        42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky        42420  South  FUR-CH-10000454
# ...

# %%
data.tail(4)
# Out:
#                Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#                Customer Name   Segment        Country         City  \
# Order ID
# CA-2017-121258   Dave Brooks  Consumer  United States   Costa Mesa
# CA-2017-121258   Dave Brooks  Consumer  United States   Costa Mesa
# CA-2017-121258   Dave Brooks  Consumer  United States   Costa Mesa
# CA-2017-119914  Chris Cortes  Consumer  United States  Westminster
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# CA-2017-121258  California        92627   West  FUR-FU-10000747
# CA-2017-121258  California        92627   West  TEC-PH-10003645
# CA-2017-121258  California        92627   West  OFF-PA-10004041
# ...

# %%
data.shape
# Out:
# (9994, 19)

# %%
data.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data.columns = ['OrderDate', 'ShipDate', 'ShipMode', 'CustomerID', 'CustomerName', 'Segment' , 'Country', 'City', 'State', 'PostalCode', 'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName' , 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
data.head(4)
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#                    CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  PostalCode Region        ProductID  \
# Order ID
# CA-2016-152156    Kentucky       42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky       42420  South  FUR-CH-10000454
# ...

# %%
data.sample(10)
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# US-2017-117534 2017-03-25 2017-03-26     First Class   CV-12295
# CA-2016-145261 2016-12-18 2016-12-21     First Class   AH-10120
# CA-2015-130974 2015-11-27 2015-11-29    Second Class   MA-17560
# CA-2014-128839 2014-09-08 2014-09-13  Standard Class   TT-21070
# CA-2017-140326 2017-09-04 2017-09-06     First Class   HW-14935
# CA-2016-101980 2016-08-19 2016-08-20     First Class   RP-19390
# CA-2015-167255 2015-09-27 2015-09-29    Second Class   RH-19510
# CA-2015-132374 2015-02-22 2015-02-24    Second Class   PS-19045
# CA-2015-147529 2015-02-07 2015-02-11  Standard Class   DK-12835
# US-2015-110569 2015-05-23 2015-05-30  Standard Class   EB-13870
#
#                           CustomerName      Segment        Country  \
# Order ID
# US-2017-117534  Christina VanderZanden     Consumer  United States
# CA-2016-145261             Adrian Hane  Home Office  United States
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, CA-2016-152156 to CA-2017-119914
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderDate     9994 non-null   datetime64[ns]
#  1   ShipDate      9994 non-null   datetime64[ns]
#  2   ShipMode      9994 non-null   object
#  3   CustomerID    9994 non-null   object
#  4   CustomerName  9994 non-null   object
#  5   Segment       9994 non-null   object
#  6   Country       9994 non-null   object
#  7   City          9994 non-null   object
#  8   State         9994 non-null   object
#  9   PostalCode    9994 non-null   int64
#  10  Region        9994 non-null   object
#  11  ProductID     9994 non-null   object
#  12  Category      9994 non-null   object
#  13  SubCategory   9994 non-null   object
#  14  ProductName   9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
# ...

# %%
data.describe()
# Out:
#          PostalCode         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.describe(include='all')
# Out:
# <ipython-input-14-589a52936347>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
# <ipython-input-14-589a52936347>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
#                   OrderDate             ShipDate        ShipMode CustomerID  \
# count                  9994                 9994            9994       9994
# unique                 1237                 1334               4        793
# top     2016-09-05 00:00:00  2015-12-16 00:00:00  Standard Class   WB-21850
# ...

# %%
sales_data=data[['OrderDate','Category','Sales']]
sales_data
# Out:
#                 OrderDate         Category     Sales
# Order ID
# CA-2016-152156 2016-11-08        Furniture  261.9600
# CA-2016-152156 2016-11-08        Furniture  731.9400
# CA-2016-138688 2016-06-12  Office Supplies   14.6200
# US-2015-108966 2015-10-11        Furniture  957.5775
# US-2015-108966 2015-10-11  Office Supplies   22.3680
# ...                   ...              ...       ...
# CA-2014-110422 2014-01-21        Furniture   25.2480
# CA-2017-121258 2017-02-26        Furniture   91.9600
# CA-2017-121258 2017-02-26       Technology  258.5760
# CA-2017-121258 2017-02-26  Office Supplies   29.6000
# CA-2017-119914 2017-05-04  Office Supplies  243.1600
#
# [9994 rows x 3 columns]

# %%
data["Sales"].count()
# Out:
# 9994

# %%
data["Sales"].mean()
# Out:
# 229.8580008304938

# %%
data["Sales"].std()
# Out:
# 623.2451005086818

# %%
data["Sales"].min()
# Out:
# 0.44399999999999995

# %%
data.isnull().sum()
# Out:
# OrderDate       0
# ShipDate        0
# ShipMode        0
# CustomerID      0
# CustomerName    0
# Segment         0
# Country         0
# City            0
# State           0
# PostalCode      0
# Region          0
# ProductID       0
# Category        0
# SubCategory     0
# ProductName     0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data.nunique()
# Out:
# OrderDate       1237
# ShipDate        1334
# ShipMode           4
# CustomerID       793
# CustomerName     793
# Segment            3
# Country            1
# City             531
# State             49
# PostalCode       631
# Region             4
# ProductID       1862
# Category           3
# SubCategory       17
# ProductName     1850
# Sales           6144
# Quantity          14
# Discount          12
# Profit          7545
# dtype: int64

# %%
data['Revenue'] = data['Sales'] - data['Profit']

# %%
data.head(4)
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#                    CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  PostalCode Region        ProductID  \
# Order ID
# CA-2016-152156    Kentucky       42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky       42420  South  FUR-CH-10000454
# ...

# %%
data['GrossPrice'] = (data['Revenue'] - data['Profit']) / data['Quantity']

# %%
data.head(4)
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#                    CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  PostalCode  ...        ProductID         Category  \
# Order ID                                ...
# CA-2016-152156    Kentucky       42420  ...  FUR-BO-10001798        Furniture
# ...

# %%
data = data.drop(columns=['GrossPrice'])

# %%
data.head(3)
# Out:
#                 OrderDate   ShipDate      ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11  Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11  Second Class   CG-12520
# CA-2016-138688 2016-06-12 2016-06-16  Second Class   DV-13045
#
#                    CustomerName    Segment        Country         City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States    Henderson
# CA-2016-152156      Claire Gute   Consumer  United States    Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States  Los Angeles
#
#                      State  PostalCode Region        ProductID  \
# Order ID
# CA-2016-152156    Kentucky       42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky       42420  South  FUR-CH-10000454
# CA-2016-138688  California       90036   West  OFF-LA-10000240
#
#                        Category SubCategory  \
# Order ID
# CA-2016-152156        Furniture   Bookcases
# ...

# %%
data[['Sales','Quantity','Profit']].groupby(['Profit'], as_index=True).sum().sort_values(by='Quantity',ascending=True)
# Out:
#              Sales  Quantity
# Profit
# 2.3086       6.790         1
# 0.2925       2.600         1
# 0.2598      12.990         1
# 0.2592       2.304         1
# 0.2353       1.448         1
# ...            ...       ...
# 6.2208     557.280        86
# 5.4432     497.664        96
# 9.3312     738.720       114
# 15.5520    842.400       130
# 0.0000   27686.847       255
#
# [7545 rows x 2 columns]

# %%
data.groupby("Category")["SubCategory"].count()
# Out:
# Category
# Furniture          2120
# Office Supplies    6026
# Technology         1847
# Name: SubCategory, dtype: int64

# %%
a = data.groupby(["Category", "SubCategory"])["Region"].count()
a
# Out:
# Category         SubCategory
# Furniture        Bookcases       228
#                  Chairs          616
#                  Furnishings     957
#                  Tables          319
# Office Supplies  Appliances      466
#                  Art             796
#                  Binders        1523
#                  Envelopes       254
#                  Fasteners       217
#                  Labels          364
#                  Paper          1370
#                  Storage         846
#                  Supplies        190
# Technology       Accessories     775
#                  Copiers          68
#                  Machines        115
#                  Phones          889
# Name: Region, dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.index
# Out:
# MultiIndex([(      'Furniture',   'Bookcases'),
#             (      'Furniture',      'Chairs'),
#             (      'Furniture', 'Furnishings'),
#             (      'Furniture',      'Tables'),
#             ('Office Supplies',  'Appliances'),
#             ('Office Supplies',         'Art'),
#             ('Office Supplies',     'Binders'),
#             ('Office Supplies',   'Envelopes'),
#             ('Office Supplies',   'Fasteners'),
#             ('Office Supplies',      'Labels'),
#             ('Office Supplies',       'Paper'),
#             ('Office Supplies',     'Storage'),
#             ('Office Supplies',    'Supplies'),
#             (     'Technology', 'Accessories'),
#             (     'Technology',     'Copiers'),
#             (     'Technology',    'Machines'),
#             (     'Technology',      'Phones')],
#            names=['Category', 'SubCategory'])

# %%
a
# Out:
# Category         SubCategory
# Furniture        Bookcases       228
#                  Chairs          616
#                  Furnishings     957
#                  Tables          319
# Office Supplies  Appliances      466
#                  Art             796
#                  Binders        1523
#                  Envelopes       254
#                  Fasteners       217
#                  Labels          364
#                  Paper          1370
#                  Storage         846
#                  Supplies        190
# Technology       Accessories     775
#                  Copiers          68
#                  Machines        115
#                  Phones          889
# Name: Region, dtype: int64

# %%
b= data.groupby(["Category", "SubCategory","ProductName"])["Region"].count()
b
# Out:
# Category    SubCategory  ProductName
# Furniture   Bookcases    Atlantic Metals Mobile 2-Shelf Bookcases, Custom Colors                                                2
#                          Atlantic Metals Mobile 3-Shelf Bookcases, Custom Colors                                                8
#                          Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors                                                6
#                          Atlantic Metals Mobile 5-Shelf Bookcases, Custom Colors                                                8
#                          Bestar Classic Bookcase                                                                                8
#                                                                                                                                ..
# Technology  Phones       iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4    5
# ...

# %%
data["ProductName"].value_counts()
# Out:
# Staple envelope                                                              48
# Staples                                                                      46
# Easy-staple paper                                                            46
# Avery Non-Stick Binders                                                      20
# Staples in misc. colors                                                      19
#                                                                              ..
# Panasonic KX MB2061 Multifunction Printer                                     1
# RCA H5401RE1 DECT 6.0 4-Line Cordless Handset With Caller ID/Call Waiting     1
# Hewlett-Packard Deskjet D4360 Printer                                         1
# Plantronics Single Ear Headset                                                1
# Konica Minolta magicolor 1690MF Multifunction Printer                         1
# Name: ProductName, Length: 1850, dtype: int64

# %%
data.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %%
data.loc[data['Category'] == 'Office Supplies']
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# ...                   ...        ...             ...        ...
# US-2016-157728 2016-09-22 2016-09-28  Standard Class   RC-19960
# CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# CA-2015-100251 2015-05-17 2015-05-23  Standard Class   DV-13465
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
# CA-2017-119914 2017-05-04 2017-05-09    Second Class   CC-12220
#
#                     CustomerName    Segment        Country             City  \
# Order ID
# CA-2016-138688   Darrin Van Huff  Corporate  United States      Los Angeles
# ...

# %%
data.loc[data['Category'] == 'Furniture']
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# CA-2014-115812 2014-06-09 2014-06-14  Standard Class   BH-11710
# ...                   ...        ...             ...        ...
# CA-2015-168088 2015-03-19 2015-03-22     First Class   CM-12655
# CA-2016-146374 2016-12-05 2016-12-10    Second Class   HE-14800
# US-2015-151435 2015-09-06 2015-09-09    Second Class   SW-20455
# CA-2014-110422 2014-01-21 2014-01-23    Second Class   TB-21400
# CA-2017-121258 2017-02-26 2017-03-03  Standard Class   DB-13060
#
#                     CustomerName      Segment        Country             City  \
# Order ID
# CA-2016-152156       Claire Gute     Consumer  United States        Henderson
# ...

# %%
data_Furniture_Bookcases = data.loc[(data['Category'] == 'Furniture') & (data['SubCategory'] == 'Bookcases')]
data_Furniture_Bookcases
# Out:
#                 OrderDate   ShipDate        ShipMode CustomerID  \
# Order ID
# CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# US-2015-150630 2015-09-17 2015-09-21  Standard Class   TB-21520
# CA-2015-117415 2015-12-27 2015-12-31  Standard Class   SN-20710
# CA-2015-102281 2015-10-12 2015-10-14     First Class   MP-17470
# CA-2015-102281 2015-10-12 2015-10-14     First Class   MP-17470
# ...                   ...        ...             ...        ...
# CA-2015-117086 2015-11-08 2015-11-12  Standard Class   QJ-19255
# CA-2016-123533 2016-11-24 2016-11-30  Standard Class   SC-20050
# CA-2017-144491 2017-03-27 2017-04-01  Standard Class   CJ-12010
# CA-2015-104948 2015-11-13 2015-11-17  Standard Class   KH-16510
# CA-2015-168088 2015-03-19 2015-03-22     First Class   CM-12655
#
#                     CustomerName      Segment        Country            City  \
# Order ID
# CA-2016-152156       Claire Gute     Consumer  United States       Henderson
# ...

# %%
data[["ProductName","Quantity"]]
# Out:
#                                                       ProductName  Quantity
# Order ID
# CA-2016-152156                  Bush Somerset Collection Bookcase         2
# CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3
# CA-2016-138688  Self-Adhesive Address Labels for Typewriters b...         2
# US-2015-108966      Bretford CR4500 Series Slim Rectangular Table         5
# US-2015-108966                     Eldon Fold 'N Roll Cart System         2
# ...                                                           ...       ...
# CA-2014-110422                             Ultra Door Pull Handle         3
# CA-2017-121258  Tenex B1-RE Series Chair Mats for Low Pile Car...         2
# CA-2017-121258                              Aastra 57i VoIP phone         2
# CA-2017-121258  It's Hot Message Books with Stickers, 2 3/4" x 5"         4
# CA-2017-119914  Acco 7-Outlet Masterpiece Power Center, Wihtou...         2
#
# [9993 rows x 2 columns]

# %%
data[["ProductName","Quantity"]].sum()
# Out:
# ProductName    Bush Somerset Collection BookcaseHon Deluxe Fa...
# Quantity                                                   37871
# dtype: object
